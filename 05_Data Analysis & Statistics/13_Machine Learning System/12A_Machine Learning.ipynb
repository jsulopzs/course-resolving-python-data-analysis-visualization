# %% [markdown]
# # Introduction to Machine Learning
#
# - Use [this CheatSheet](https://www.craft.do/s/bj8CiGxswdNZl3/b/2CC9B9A0-7484-45FD-9097-52ED788D4925/The-Machine-Learning-System) to work better with the following exercises.

# %%
???

# %% [markdown]
# ## [ ] Load the data

# %%
import pandas as pd

df_premier = pd.read_excel('premier_league.xlsx', index_col=0)
df_premier
# Out:
#                           goals  points
# team
# Manchester City              99      93
# Liverpool                    94      92
# Chelsea                      76      74
# Tottenham Hotspur            69      71
# Arsenal                      61      69
# Manchester United            57      58
# West Ham United              60      56
# Leicester City               62      52
# Brighton and Hove Albion     42      51
# Wolverhampton Wanderers      38      51
# Newcastle United             44      49
# Crystal Palace               50      48
# Brentford                    48      46
# Aston Villa                  52      45
# Southampton                  43      40
# Everton                      43      39
# Leeds United                 42      38
# Burnley                      34      35
# Watford                      34      23
# Norwich City                 23      22

# %% [markdown]
# $$
# points = (a) + (b) \cdot goals
# $$

# %% [markdown]
# ## Select the variables for the model

# %% [markdown]
# 1. y: the variable you want to predict
# 2. X: the variable you will use to calculate the prediction y

# %% [markdown]
# ## The Linear Regression ML Model

# %%
df_premier
# Out:
#                           goals  points
# team
# Manchester City              99      93
# Liverpool                    94      92
# Chelsea                      76      74
# Tottenham Hotspur            69      71
# Arsenal                      61      69
# Manchester United            57      58
# West Ham United              60      56
# Leicester City               62      52
# Brighton and Hove Albion     42      51
# Wolverhampton Wanderers      38      51
# Newcastle United             44      49
# Crystal Palace               50      48
# Brentford                    48      46
# Aston Villa                  52      45
# Southampton                  43      40
# Everton                      43      39
# Leeds United                 42      38
# Burnley                      34      35
# Watford                      34      23
# Norwich City                 23      22

# %%
sns.scatterplot(data=df_premier, x='goals', y='points')
# Out:
# <Axes: xlabel='goals', ylabel='points'>

# %%
sklearn

# %%
from sklearn.linear_model import LinearRegression

# %%
explanatory = df_premier[['goals']]
target = df_premier[['points']]

# %%
model = LinearRegression()

# %%
model.__dict__
# Out:
# {'fit_intercept': True, 'copy_X': True, 'n_jobs': None, 'positive': False}

# %%
model.fit(X=explanatory, y=target)
# Out:
# LinearRegression()

# %%
model.__dict__
# Out:
# {'fit_intercept': True,
#  'copy_X': True,
#  'n_jobs': None,
#  'positive': False,
#  'feature_names_in_': array(['goals'], dtype=object),
#  'n_features_in_': 1,
#  'coef_': array([[0.94527149]]),
#  'rank_': 1,
#  'singular_': array([84.79946934]),
#  'intercept_': array([1.98071187])}

# %%
y_pred = model.predict(X=explanatory)

# %%
df_premier['predictions'] = y_pred

# %%
import seaborn as sns

# %%
sns.scatterplot(data=df_premier, x='goals', y='points')
sns.scatterplot(data=df_premier, x='goals', y='predictions')
sns.lineplot(data=df_premier, x='goals', y='predictions', c='orange')
# Out:
# <Axes: xlabel='goals', ylabel='points'>

# %% [markdown]
# ### Fit the model with the data

# %% [markdown]
# ### Predictions

# %% [markdown]
# #### Calculate the predictions

# %% [markdown]
# ### Model evaluation

# %% [markdown]
# #### Calculate the model's score

# %% [markdown]
# ## The K Nearest Neighbours ML Model

# %% [markdown]
# ### Fit the model with the data

# %% [markdown]
# ### Predictions

# %% [markdown]
# #### Calculate the predictions

# %% [markdown]
# ### Model evaluation

# %% [markdown]
# #### Calculate the model's score

# %% [markdown]
# ## The Random Forest ML Model

# %% [markdown]
# ### Fit the model with the data

# %% [markdown]
# ### Predictions

# %% [markdown]
# #### Calculate the predictions

# %% [markdown]
# ### Model evaluation

# %% [markdown]
# #### Calculate the model's score
