# %% [markdown]
# # Filtering the DataFrame with Boolean Arrays (Masks)
#
# - Use [this CheatSheet](https://www.craft.do/s/G80r1dqrQKrjTb/b/F80131CD-4914-414F-8B93-C03B5D1AFCD5/DataFrame) to work better with the following exercises.

# %% [markdown]
# In this chapter, you will learn how to select specific parts of the data (masking) based on conditions we'll ask in the questions.
#
# Framework to work on masking the DataFrames:
#
# 1. Identify the column of the condition
# 2. Access the column `df.column`
# 3. Compare column values based on the condition `df.column == value`; operators:
#     1. Equal `==`
#     2. Not equal `!=`
#     2. Greater `>`
#     3. Greater or equal `>=`
# 4. Save the boolean array into the mask `mask = df.column == value`
# 5. Filter the DataFrame with the mask `df[mask]`
#
# ```python
# df.column
# df.column == value
# mask = df.column == value
# df[mask]
# ```

# %% [markdown]
# ## Load the data

# %% [markdown]
# The data is taken from [this kaggle repository](https://www.kaggle.com/datasets/azminetoushikwasi/ucl-202122-uefa-champions-league?select=goals.csv).

# %%
import pandas as pd

df_players = pd.read_csv('key_stats.csv', index_col='player_name')
df_players
# Out:
#                         club    position  minutes_played  match_played  goals  \
# player_name
# Courtois         Real Madrid  Goalkeeper            1230            13      0
# Vinícius Júnior  Real Madrid     Forward            1199            13      4
# ...                      ...         ...             ...           ...    ...
# Maouassa         Club Brugge    Defender               1             1      0
# Zesiger           Young Boys    Defender               1             1      0
#
#                  assists distance_covered
# player_name
# Courtois               0             64.2
# Vinícius Júnior        6            133.0
# ...                  ...              ...
# Maouassa               0              0.2
# Zesiger                0                -
#
# [747 rows x 7 columns]

# %% [markdown]
# ## Simple conditions

# %% [markdown]
# ### Players who scored 10 or more goals

# %%
mask_goals = df_players.goals >= 10

df_players[mask_goals]
# Out:
#                     club position  minutes_played  match_played  goals  \
# player_name
# Benzema      Real Madrid  Forward            1106            12     15
# Lewandowski       Bayern  Forward             876            10     13
# Haller              Ajax  Forward             668             8     11
#
#              assists distance_covered
# player_name
# Benzema            1            121.5
# Lewandowski        3             99.7
# Haller             1             82.2

# %% [markdown]
# ### Players who assisted 5 or more times

# %%
mask_assists = df_players.assists >= 5

df_players[mask_assists]
# Out:
#                         club    position  minutes_played  match_played  goals  \
# player_name
# Vinícius Júnior  Real Madrid     Forward            1199            13      4
# Sané                  Bayern  Midfielder             798            10      6
# Antony                  Ajax     Forward             577             7      2
# Bruno Fernandes  Man. United  Midfielder             520             7      0
#
#                  assists distance_covered
# player_name
# Vinícius Júnior        6            133.0
# Sané                   6               94
# Antony                 5             65.1
# Bruno Fernandes        7             58.4

# %% [markdown]
# ## Multiple conditions

# %% [markdown]
# ### Filter the goalkeepers who gave at least one assist

# %%
mask_goalkeeper = df_players.position == 'Goalkeeper'
mask_assists = df_players.assists > 0

df_players[mask_goalkeeper & mask_assists]
# Out:
#                club    position  minutes_played  match_played  goals  assists  \
# player_name
# Neuer        Bayern  Goalkeeper             810             9      0        1
#
#             distance_covered
# player_name
# Neuer                   51.2

# %%
from IPython.lib.display import YouTubeVideo
YouTubeVideo('g4mPT36U1-s')

# %% [markdown]
# ### Forwards with at least 700 minutes played

# %%
mask_minutes_played = df_players.minutes_played >= 700
mask_position = df_players.position == 'Forward'

df_players[mask_minutes_played & mask_position]
# Out:
#                         club position  minutes_played  match_played  goals  \
# player_name
# Vinícius Júnior  Real Madrid  Forward            1199            13      4
# Benzema          Real Madrid  Forward            1106            12     15
# Salah              Liverpool  Forward            1008            13      8
# Lewandowski           Bayern  Forward             876            10     13
# Müller                Bayern  Forward             778            10      4
# Rafa Silva           Benfica  Forward             704             9      1
#
#                  assists distance_covered
# player_name
# Vinícius Júnior        6            133.0
# Benzema                1            121.5
# Salah                  2            112.0
# Lewandowski            3             99.7
# Müller                 3             98.5
# Rafa Silva             1             85.7

# %% [markdown]
# ### Real Madrid players who scored

# %%
mask_club = df_players.club == 'Real Madrid'
mask_goals = df_players.goals > 0

df_players[mask_goals & mask_club]
# Out:
#                         club    position  minutes_played  match_played  goals  \
# player_name
# Vinícius Júnior  Real Madrid     Forward            1199            13      4
# Benzema          Real Madrid     Forward            1106            12     15
# Alaba            Real Madrid    Defender            1040            12      1
# Kroos            Real Madrid  Midfielder             902            12      2
# Rodrygo          Real Madrid     Forward             505            11      5
# Asensio          Real Madrid     Forward             207             8      1
#
#                  assists distance_covered
# player_name
# Vinícius Júnior        6            133.0
# Benzema                1            121.5
# Alaba                  0            112.3
# Kroos                  0            116.5
# Rodrygo                2             65.7
# Asensio                2             28.4

# %% [markdown]
# ### FC Barcelona players who scored

# %%
mask_club = df_players.club == 'Barcelona'
mask_goals = df_players.goals > 0

df_players[mask_goals & mask_club]
# Out:
#                   club  position  minutes_played  match_played  goals  \
# player_name
# Piqué        Barcelona  Defender             393             5      1
# Fati         Barcelona   Forward             154             3      1
#
#              assists distance_covered
# player_name
# Piqué              0               44
# Fati               0             19.7

# %% [markdown]
# ### Real Madrid players who scored and assisted

# %%
mask_club = df_players.club == 'Real Madrid'

mask_goals = df_players.goals > 0
mask_assists = df_players.assists > 0

df_players[mask_assists & mask_goals & mask_club]
# Out:
#                         club position  minutes_played  match_played  goals  \
# player_name
# Vinícius Júnior  Real Madrid  Forward            1199            13      4
# Benzema          Real Madrid  Forward            1106            12     15
# Rodrygo          Real Madrid  Forward             505            11      5
# Asensio          Real Madrid  Forward             207             8      1
#
#                  assists distance_covered
# player_name
# Vinícius Júnior        6            133.0
# Benzema                1            121.5
# Rodrygo                2             65.7
# Asensio                2             28.4

# %% [markdown]
# ### FC Barcelona players who scored and assisted

# %%
mask_club = df_players.club == 'Barcelona'

mask_goals = df_players.goals > 0
mask_assists = df_players.assists > 0

df_players[mask_assists & mask_goals & mask_club]
# Out:
# Empty DataFrame
# Columns: [club, position, minutes_played, match_played, goals, assists, distance_covered]
# Index: []

# %% [markdown]
# ### Defenders who scored and assisted

# %%
mask_position = df_players.position == 'Defender'
mask_assists = df_players.assists > 0
mask_goals = df_players.goals > 0

df_players[mask_assists & mask_goals & mask_position]
# Out:
#                     club  position  minutes_played  match_played  goals  \
# player_name
# João Cancelo   Man. City  Defender             840             9      2
# Azpilicueta      Chelsea  Defender             679             9      1
# Christensen      Chelsea  Defender             603             8      1
# Blind               Ajax  Defender             572             8      1
# Rakitskyy          Zenit  Defender             497             6      1
# Mukiele          Leipzig  Defender             484             6      1
# Renan Lodi      Atlético  Defender             478            10      1
# Palomino        Atalanta  Defender             450             5      1
# Hefti         Young Boys  Defender             386             6      1
#
#               assists distance_covered
# player_name
# João Cancelo        3            100.3
# Azpilicueta         1               82
# Christensen         1             62.6
# Blind               1             70.9
# Rakitskyy           2             52.3
# Mukiele             1               57
# Renan Lodi          2             61.7
# Palomino            1             50.5
# Hefti               1             38.8

# %% [markdown]
# ## Combine masks with unions and intersections

# %% [markdown]
# ### FC Barcelona players who scored or assisted

# %%
mask_club = df_players.club == 'Barcelona'

mask_goals = df_players.goals > 0
mask_assists = df_players.assists > 0

df_players[(mask_goals | mask_assists) & mask_club]
# Out:
#                   club  position  minutes_played  match_played  goals  \
# player_name
# Piqué        Barcelona  Defender             393             5      1
# Jordi Alba   Barcelona  Defender             375             5      0
# Fati         Barcelona   Forward             154             3      1
#
#              assists distance_covered
# player_name
# Piqué              0               44
# Jordi Alba         1             45.8
# Fati               0             19.7

# %% [markdown]
# ### Liverpool players who scored or assisted

# %%
mask_club = df_players.club == 'Liverpool'

mask_goals = df_players.goals > 0
mask_assists = df_players.assists > 0

df_players[(mask_goals | mask_assists) & mask_club]
# Out:
#                   club    position  minutes_played  match_played  goals  \
# player_name
# Salah        Liverpool     Forward            1008            13      8
# Fabinho      Liverpool  Midfielder             849            13      1
# ...                ...         ...             ...           ...    ...
# Origi        Liverpool     Forward             187             7      1
# Jones        Liverpool  Midfielder             185             4      0
#
#              assists distance_covered
# player_name
# Salah              2            112.0
# Fabinho            0            105.5
# ...              ...              ...
# Origi              1             23.8
# Jones              2             27.1
#
# [18 rows x 7 columns]
